# %% [markdown]
# [Lecture 9: AI for Science](https://www.youtube.com/watch?v=QZxcTZj0L-M&list=PLtBw6njQRU-rwp5__7C0oIVt26ZgjG9NI&index=17) (back to 2022 lectures because the last 2 2023s haven't been posted.)

# %% [markdown]
# Q: is ML about data, about compute, or about algorithms?

# %% [markdown]
# potential problems could be on the scale of atoms or planet.

# %% [markdown]
# this math looks cool. integration as convolution? I need to learn more.

# %% [markdown]
# we can train a neural net to solve PDEs.

# %% [markdown]
# sometimes we map to Fourier domain, train our model there, and map out.
# I think this is a standard set of steps for lots of problems but I don't know nearly as much as I should about Fourier transforms.

# %% [markdown]
# learn more about Fourier Neural Operator.

# %% [markdown]
# if you have the equation why not just use it explicitly? maybe this is what the ex of the Shrödinger equation explains. too expensive to simulate whole system and we want something cheap that's pretty good.

# %% [markdown]
# sometimes we have the equation and we want to solve for the initial conditions using a backward operator.

# %% [markdown]
# we can also use neural networks on chaotic systems.

# %% [markdown]
# reflections:

# %% [markdown]
# I didn't learn a much this lecture. there's a few areas where I am now interested in learning about the application of machine learning, but htat learning is still ahead of me, as I did not take much in terms of technical details from this lecture.
# PDEs are important. NNs can simulate complex processes very efficiently. I think I want to work in science.
